# %%
# Import
import pandas as pd

# %% [markdown]
# ### Load CSV

# %%
# Load CSV
path = '../data/gsearch_jobs.csv'
data = pd.read_csv(path)

# Preview dataset
data.head()
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0      0              Data analyst | Wichita, KS | Fulltime
# 1           1      1             Quality Measures Data Analyst (Remote)
# 2           2      2                                Senior Data Analyst
# 3           3      3  EDI Data Analyst/Business Systems Analyst III ...
# 4           4      4  Data Analyst that can read and find places onl...
#
#    company_name            location                    via  \
# 0          Dice      Wichita, KS              via LinkedIn
# 1  Talentify.io           Anywhere            via LinkedIn
# 2     Naviguard    United States     via My Stateline Jobs
# 3  Talentify.io           Anywhere            via LinkedIn
# 4        Upwork           Anywhere              via Upwork
#
#                                          description  \
# 0  Role: Data analyst Location: Wichita, KS (Day ...
# 1  Talentify helps candidates around the world to...
# ...

# %%
# View columns to determine which columns are necessary to keep
data.columns
# Out:
# Index(['Unnamed: 0', 'index', 'title', 'company_name', 'location', 'via',
#        'description', 'extensions', 'job_id', 'thumbnail', 'posted_at',
#        'schedule_type', 'work_from_home', 'salary', 'search_term', 'date_time',
#        'search_location', 'commute_time', 'salary_pay', 'salary_rate',
#        'salary_avg', 'salary_min', 'salary_max', 'salary_hourly',
#        'salary_yearly', 'salary_standardized', 'description_tokens'],
#       dtype='object')

# %%
# Only keep necessary columns
data_clean = data[['title', 'company_name', 'location', 'via', 'description', 'extensions', 'schedule_type', 'work_from_home', 'salary_hourly', 'salary_yearly', 'salary_standardized', 'description_tokens']]
data_clean.head()
# Out:
#                                                title  company_name  \
# 0              Data analyst | Wichita, KS | Fulltime          Dice
# 1             Quality Measures Data Analyst (Remote)  Talentify.io
# 2                                Senior Data Analyst     Naviguard
# 3  EDI Data Analyst/Business Systems Analyst III ...  Talentify.io
# 4  Data Analyst that can read and find places onl...        Upwork
#
#              location                    via  \
# 0      Wichita, KS              via LinkedIn
# 1           Anywhere            via LinkedIn
# 2    United States     via My Stateline Jobs
# 3           Anywhere            via LinkedIn
# 4           Anywhere              via Upwork
#
#                                          description  \
# 0  Role: Data analyst Location: Wichita, KS (Day ...
# 1  Talentify helps candidates around the world to...
# 2  Senior Data Analyst\nAs a Senior Data Analyst ...
# 3  Talentify helps candidates around the world to...
# ...

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20435 entries, 0 to 20434
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                20435 non-null  object
#  1   company_name         20435 non-null  object
#  2   location             20420 non-null  object
#  3   via                  20435 non-null  object
#  4   description          20435 non-null  object
#  5   extensions           20435 non-null  object
#  6   schedule_type        20306 non-null  object
#  7   work_from_home       9093 non-null   object
#  8   salary_hourly        2286 non-null   float64
#  9   salary_yearly        1601 non-null   float64
#  10  salary_standardized  3893 non-null   float64
#  11  description_tokens   20435 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 1.9+ MB

# %%
from json import loads, dumps
import json

# %%
# Export clean data to json file

result = data_clean.to_json(orient="records")
parsed = loads(result)

# %%
with open('../data/clean_data.json', 'w') as fp:
    json.dump(parsed, fp)
